# %% [markdown]
# # matplotlib
#
# References:
# - [Matplotlib API](https://matplotlib.org/stable/api/index.html)

# %% [markdown]
# ## General Plotting
# - Plot Types: bar, barbs, barh, boxplot, hist, pie, plot, plot_date, polar, psd, quiver, scatter, specgram, spy, stackplot, stairs, stem, step, streamplot, violin

# %%
import matplotlib.pyplot as plt

fig, axes = plot.subplots(numrows, numcols, figsize=(width, height), sharex=True, sharey=False)
axes = axes.flatten()

axes[0] = plt.boxplot(x,y)
plt.xlabel('X axis label')
plt.ylabel('Y axis label)
plt.title('Title')
plt.axhline(y=yval)
plt.axvline(x=xval)
text = axes[0].text(0.05, 0.95, 'string', transform=axes.transAxes)
text.set_alpha(0.5)
plt.legend(bbox_to_anchor=(1.04,1), loc='upper left')
